# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayan02-coder/Computational_Satistics/blob/main/Mock%20Practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Factor* *Analysis*

# %%
pip install factor_analyzer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from factor_analyzer import FactorAnalyzer

# %%
import pandas as pd

# %%
csv= pd.read_csv("bfi.csv")

# %%
csv.columns
# Out:
# Index(['Unnamed: 0', 'A1', 'A2', 'A3', 'A4', 'A5', 'C1', 'C2', 'C3', 'C4',
#        'C5', 'E1', 'E2', 'E3', 'E4', 'E5', 'N1', 'N2', 'N3', 'N4', 'N5', 'O1',
#        'O2', 'O3', 'O4', 'O5', 'gender', 'education', 'age'],
#       dtype='object')

# %%
csv.head()
# Out:
#    Unnamed: 0   A1   A2   A3   A4   A5   C1   C2   C3   C4  ...   N4   N5  \
# 0       61617  2.0  4.0  3.0  4.0  4.0  2.0  3.0  3.0  4.0  ...  2.0  3.0
# 1       61618  2.0  4.0  5.0  2.0  5.0  5.0  4.0  4.0  3.0  ...  5.0  5.0
# 2       61620  5.0  4.0  5.0  4.0  4.0  4.0  5.0  4.0  2.0  ...  2.0  3.0
# 3       61621  4.0  4.0  6.0  5.0  5.0  4.0  4.0  3.0  5.0  ...  4.0  1.0
# 4       61622  2.0  3.0  3.0  4.0  5.0  4.0  4.0  5.0  3.0  ...  4.0  3.0
#
#     O1  O2   O3   O4   O5  gender  education  age
# 0  3.0   6  3.0  4.0  3.0       1        NaN   16
# 1  4.0   2  4.0  3.0  3.0       2        NaN   18
# 2  4.0   2  5.0  5.0  2.0       2        NaN   17
# 3  3.0   3  4.0  3.0  5.0       2        NaN   17
# 4  3.0   3  4.0  3.0  3.0       1        NaN   17
#
# [5 rows x 29 columns]

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2800 non-null   int64
#  1   A1          2784 non-null   float64
#  2   A2          2773 non-null   float64
#  3   A3          2774 non-null   float64
#  4   A4          2781 non-null   float64
#  5   A5          2784 non-null   float64
#  6   C1          2779 non-null   float64
#  7   C2          2776 non-null   float64
#  8   C3          2780 non-null   float64
#  9   C4          2774 non-null   float64
#  10  C5          2784 non-null   float64
#  11  E1          2777 non-null   float64
#  12  E2          2784 non-null   float64
#  13  E3          2775 non-null   float64
#  14  E4          2791 non-null   float64
#  15  E5          2779 non-null   float64
#  16  N1          2778 non-null   float64
#  17  N2          2779 non-null   float64
# ...

# %%
csv.drop(['gender','education','age'],axis= 1,inplace=True)

# %%
csv.head()
# Out:
#    Unnamed: 0   A1   A2   A3   A4   A5   C1   C2   C3   C4  ...   N1   N2  \
# 0       61617  2.0  4.0  3.0  4.0  4.0  2.0  3.0  3.0  4.0  ...  3.0  4.0
# 1       61618  2.0  4.0  5.0  2.0  5.0  5.0  4.0  4.0  3.0  ...  3.0  3.0
# 2       61620  5.0  4.0  5.0  4.0  4.0  4.0  5.0  4.0  2.0  ...  4.0  5.0
# 3       61621  4.0  4.0  6.0  5.0  5.0  4.0  4.0  3.0  5.0  ...  2.0  5.0
# 4       61622  2.0  3.0  3.0  4.0  5.0  4.0  4.0  5.0  3.0  ...  2.0  3.0
#
#     N3   N4   N5   O1  O2   O3   O4   O5
# 0  2.0  2.0  3.0  3.0   6  3.0  4.0  3.0
# 1  3.0  5.0  5.0  4.0   2  4.0  3.0  3.0
# 2  4.0  2.0  3.0  4.0   2  5.0  5.0  2.0
# 3  2.0  4.0  1.0  3.0   3  4.0  3.0  5.0
# 4  4.0  4.0  3.0  3.0   3  4.0  3.0  3.0
#
# [5 rows x 26 columns]

# %%
csv.dropna(inplace=True)

# %%
csv.head()
# Out:
#    Unnamed: 0   A1   A2   A3   A4   A5   C1   C2   C3   C4  ...   N1   N2  \
# 0       61617  2.0  4.0  3.0  4.0  4.0  2.0  3.0  3.0  4.0  ...  3.0  4.0
# 1       61618  2.0  4.0  5.0  2.0  5.0  5.0  4.0  4.0  3.0  ...  3.0  3.0
# 2       61620  5.0  4.0  5.0  4.0  4.0  4.0  5.0  4.0  2.0  ...  4.0  5.0
# 3       61621  4.0  4.0  6.0  5.0  5.0  4.0  4.0  3.0  5.0  ...  2.0  5.0
# 4       61622  2.0  3.0  3.0  4.0  5.0  4.0  4.0  5.0  3.0  ...  2.0  3.0
#
#     N3   N4   N5   O1  O2   O3   O4   O5
# 0  2.0  2.0  3.0  3.0   6  3.0  4.0  3.0
# 1  3.0  5.0  5.0  4.0   2  4.0  3.0  3.0
# 2  4.0  2.0  3.0  4.0   2  5.0  5.0  2.0
# 3  2.0  4.0  1.0  3.0   3  4.0  3.0  5.0
# 4  4.0  4.0  3.0  3.0   3  4.0  3.0  3.0
#
# [5 rows x 26 columns]

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2436 entries, 0 to 2799
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2436 non-null   int64
#  1   A1          2436 non-null   float64
#  2   A2          2436 non-null   float64
#  3   A3          2436 non-null   float64
#  4   A4          2436 non-null   float64
#  5   A5          2436 non-null   float64
#  6   C1          2436 non-null   float64
#  7   C2          2436 non-null   float64
#  8   C3          2436 non-null   float64
#  9   C4          2436 non-null   float64
#  10  C5          2436 non-null   float64
#  11  E1          2436 non-null   float64
#  12  E2          2436 non-null   float64
#  13  E3          2436 non-null   float64
#  14  E4          2436 non-null   float64
#  15  E5          2436 non-null   float64
#  16  N1          2436 non-null   float64
#  17  N2          2436 non-null   float64
# ...

# %%
csv.head()
# Out:
#    Unnamed: 0   A1   A2   A3   A4   A5   C1   C2   C3   C4  ...   N1   N2  \
# 0       61617  2.0  4.0  3.0  4.0  4.0  2.0  3.0  3.0  4.0  ...  3.0  4.0
# 1       61618  2.0  4.0  5.0  2.0  5.0  5.0  4.0  4.0  3.0  ...  3.0  3.0
# 2       61620  5.0  4.0  5.0  4.0  4.0  4.0  5.0  4.0  2.0  ...  4.0  5.0
# 3       61621  4.0  4.0  6.0  5.0  5.0  4.0  4.0  3.0  5.0  ...  2.0  5.0
# 4       61622  2.0  3.0  3.0  4.0  5.0  4.0  4.0  5.0  3.0  ...  2.0  3.0
#
#     N3   N4   N5   O1  O2   O3   O4   O5
# 0  2.0  2.0  3.0  3.0   6  3.0  4.0  3.0
# 1  3.0  5.0  5.0  4.0   2  4.0  3.0  3.0
# 2  4.0  2.0  3.0  4.0   2  5.0  5.0  2.0
# 3  2.0  4.0  1.0  3.0   3  4.0  3.0  5.0
# 4  4.0  4.0  3.0  3.0   3  4.0  3.0  3.0
#
# [5 rows x 26 columns]

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity

# %%
chi_square,p=calculate_bartlett_sphericity(csv)
chi_square ,p
# Out:
# (18184.30630782077, 0.0)

# %%
from factor_analyzer.factor_analyzer import calculate_kmo

# %%
kmo_all,kmo_model=calculate_kmo(csv)
print(kmo_all,kmo_model)
# Out:
# [0.61117947 0.75423878 0.83684634 0.87024471 0.87804271 0.90287407
#  0.84310042 0.7959044  0.85096212 0.8265822  0.86415543 0.83871541
#  0.88380142 0.89688431 0.87747671 0.89355679 0.77957992 0.77992832
#  0.86232485 0.88530496 0.86026287 0.85833622 0.78028961 0.84440323
#  0.76978907 0.76164188] 0.8483267027192372

# %%
kmo_model
# Out:
# 0.8483267027192372

# %%
csv.describe()
# Out:
#          Unnamed: 0           A1           A2           A3           A4  \
# count   2436.000000  2436.000000  2436.000000  2436.000000  2436.000000
# mean   64593.297209     2.406404     4.797209     4.598522     4.687603
# std     1732.091241     1.407177     1.179535     1.311355     1.485213
# min    61617.000000     1.000000     1.000000     1.000000     1.000000
# 25%    63076.500000     1.000000     4.000000     4.000000     4.000000
# 50%    64582.000000     2.000000     5.000000     5.000000     5.000000
# 75%    66092.250000     3.000000     6.000000     6.000000     6.000000
# max    67560.000000     6.000000     6.000000     6.000000     6.000000
#
#                 A5           C1           C2           C3           C4  ...  \
# count  2436.000000  2436.000000  2436.000000  2436.000000  2436.000000  ...
# mean      4.543514     4.525041     4.372332     4.300082     2.549672  ...
# std       1.270804     1.235258     1.319152     1.291202     1.376689  ...
# ...

# %%
csv.corr()
# Out:
#             Unnamed: 0        A1        A2        A3        A4        A5  \
# Unnamed: 0    1.000000  0.045092 -0.050774 -0.015351  0.011072  0.003894
# A1            0.045092  1.000000 -0.350905 -0.273636 -0.156754 -0.192698
# A2           -0.050774 -0.350905  1.000000  0.503041  0.350856  0.397400
# A3           -0.015351 -0.273636  0.503041  1.000000  0.384918  0.515679
# A4            0.011072 -0.156754  0.350856  0.384918  1.000000  0.325644
# A5            0.003894 -0.192698  0.397400  0.515679  0.325644  1.000000
# C1            0.043056  0.014698  0.102983  0.114211  0.094813  0.134692
# C2            0.042020  0.012918  0.129574  0.146511  0.226454  0.116863
# C3           -0.011260 -0.020587  0.188818  0.129391  0.133065  0.130820
# C4           -0.004108  0.115074 -0.146295 -0.121116 -0.172271 -0.125531
# C5           -0.010456  0.038293 -0.121106 -0.153811 -0.249675 -0.167036
# E1            0.046068  0.107178 -0.222280 -0.210366 -0.133600 -0.252310
# ...

# %%
csv.count()
# Out:
# Unnamed: 0    2436
# A1            2436
# A2            2436
# A3            2436
# A4            2436
# A5            2436
# C1            2436
# C2            2436
# C3            2436
# C4            2436
# C5            2436
# E1            2436
# E2            2436
# E3            2436
# E4            2436
# E5            2436
# N1            2436
# N2            2436
# N3            2436
# N4            2436
# N5            2436
# O1            2436
# O2            2436
# O3            2436
# O4            2436
# O5            2436
# dtype: int64

# %%
FACTOR = FactorAnalyzer(n_factors=2,rotation= 'varimax')

# %%
FACTOR.get_factor_variance
# Out:
# <bound method FactorAnalyzer.get_factor_variance of FactorAnalyzer(n_factors=2, rotation='varimax')>

# %%
FACTOR = FactorAnalyzer()

# %%
FACTOR.fit(csv)
# Out:
# FactorAnalyzer(rotation_kwargs={})

# %%
FACTOR.loadings_
# Out:
# array([[-0.07131035, -0.01751926,  0.05405798],
#        [-0.23219058,  0.08334477,  0.03458871],
#        [ 0.5413533 ,  0.06211685,  0.04667964],
#        [ 0.64586903,  0.04331579,  0.00192803],
#        [ 0.3910012 , -0.0592843 ,  0.07552545],
#        [ 0.64743433, -0.08504573, -0.01610074],
#        [-0.012761  ,  0.08019221,  0.61189813],
#        [-0.00668553,  0.14317342,  0.63664785],
#        [-0.00354386, -0.00201999,  0.48602329],
#        [ 0.05511348,  0.18756638, -0.63069868],
#        [-0.05185813,  0.26189667, -0.46496583],
#        [-0.53560024,  0.02486523,  0.09320605],
#        [-0.57445534,  0.2160911 , -0.01194907],
#        [ 0.6069387 ,  0.09092885,  0.0968013 ],
#        [ 0.69550544, -0.10590157, -0.06884823],
#        [ 0.4264341 ,  0.09512995,  0.30777364],
#        [ 0.00397076,  0.74125646, -0.06354794],
#        [-0.02255664,  0.74077167, -0.01052292],
#        [ 0.01980718,  0.74281971, -0.04895261],
#        [-0.1871232 ,  0.58791351, -0.08352484],
# ...

# %%
eigenvalue, v= FACTOR.get_eigenvalues()

# %%
eigenvalue
# Out:
# array([5.13457985, 2.75337527, 2.14814212, 1.85250623, 1.54846254,
#        1.11066151, 0.98067695, 0.82430872, 0.79516217, 0.71828982,
#        0.68602566, 0.67614851, 0.65177562, 0.62297416, 0.59623084,
#        0.56244599, 0.54329886, 0.51434031, 0.49437154, 0.48263949,
#        0.44865495, 0.42280589, 0.40028481, 0.38773757, 0.38183723,
#        0.2622634 ])

# %%
csv.describe()
# Out:
#          Unnamed: 0           A1           A2           A3           A4  \
# count   2436.000000  2436.000000  2436.000000  2436.000000  2436.000000
# mean   64593.297209     2.406404     4.797209     4.598522     4.687603
# std     1732.091241     1.407177     1.179535     1.311355     1.485213
# min    61617.000000     1.000000     1.000000     1.000000     1.000000
# 25%    63076.500000     1.000000     4.000000     4.000000     4.000000
# 50%    64582.000000     2.000000     5.000000     5.000000     5.000000
# 75%    66092.250000     3.000000     6.000000     6.000000     6.000000
# max    67560.000000     6.000000     6.000000     6.000000     6.000000
#
#                 A5           C1           C2           C3           C4  ...  \
# count  2436.000000  2436.000000  2436.000000  2436.000000  2436.000000  ...
# mean      4.543514     4.525041     4.372332     4.300082     2.549672  ...
# std       1.270804     1.235258     1.319152     1.291202     1.376689  ...
# ...

# %%
a =csv.shape[1]+1
print(a)
# Out:
# 27

# %%
import matplotlib.pyplot as plt

plt.scatter(range(1,a),eigenvalue)
plt.plot(range(1,a),eigenvalue)
plt.title('Elbo Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.show()

# %%
FACTOR.get_factor_variance()
# Out:
# (array([3.1912033 , 2.58653631, 2.12619304]),
#  array([0.12273859, 0.09948217, 0.08177666]),
#  array([0.12273859, 0.22222075, 0.30399741]))

# %%
FACTOR.get_communalities()
# Out:
# array([0.00831436, 0.0620552 , 0.29910088, 0.41902678, 0.16210066,
#        0.42666322, 0.38101295, 0.42586381, 0.23623528, 0.43599946,
#        0.28747236, 0.29617326, 0.37683708, 0.38601314, 0.49968303,
#        0.28562036, 0.55351525, 0.5493622 , 0.5545698 , 0.38763379,
#        0.26558527, 0.13388405, 0.10344118, 0.19523425, 0.09464884,
#        0.07788619])

# %%
FACTOR.get_uniquenesses()
# Out:
# array([0.99168564, 0.9379448 , 0.70089912, 0.58097322, 0.83789934,
#        0.57333678, 0.61898705, 0.57413619, 0.76376472, 0.56400054,
#        0.71252764, 0.70382674, 0.62316292, 0.61398686, 0.50031697,
#        0.71437964, 0.44648475, 0.4506378 , 0.4454302 , 0.61236621,
#        0.73441473, 0.86611595, 0.89655882, 0.80476575, 0.90535116,
#        0.92211381])
